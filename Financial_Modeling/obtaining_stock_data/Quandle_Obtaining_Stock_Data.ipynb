# %% [markdown]
# # Obtaining Stock Data
#
# ## Importing Libraries

# %%
from sys import getsizeof
import pandas as pd
import numpy as np
import quandl

# %% [markdown]
# -----
# ## Using Quandle's API to Obtain Historical Stock Data
#
# ### Instantiating my API Key:

# %%
quandl.ApiConfig.api_key = "9tQnPMV9zakeCm4K6S5X"

# %%
# quandl.get('NYXDATA/MARKET_CREDIT')

# %% [markdown]
# --------
#
# ## Querying Stock Prices
#
# ### Querying the following Companies:
# - [Facebook](#Facebook)
# - [Google](#Google)
# - [Microsoft](#Microsoft)
# - [Twitter](#Twitter)
# - [IBM](#IBM)
# - [Apple](#Apple)
# - [J.P. Morgan](#JPM)
# - [Goldman Sachs](#GS)
# - [BlackRock](#BR)
# - [DOW Jones](#DOW)
# - [Moodys](#Moodys)
#
# ------------

# %% [markdown]
#  <a class="anchor" id="Facebook"></a>
# ## Facebook's Financial History Since its IPO:

# %%
fb = quandl.get(['WIKI/FB'])

# %%
fb.head()
# Out:
#             WIKI/FB - Open  WIKI/FB - High  WIKI/FB - Low  WIKI/FB - Close  \
# Date
# 2012-05-18           42.05           45.00          38.00          38.2318
# 2012-05-21           36.53           36.66          33.00          34.0300
# 2012-05-22           32.61           33.59          30.94          31.0000
# 2012-05-23           31.37           32.50          31.36          32.0000
# 2012-05-24           32.95           33.21          31.77          33.0300
#
#             WIKI/FB - Volume  WIKI/FB - Ex-Dividend  WIKI/FB - Split Ratio  \
# Date
# 2012-05-18       573576400.0                    0.0                    1.0
# 2012-05-21       168192700.0                    0.0                    1.0
# 2012-05-22       101786600.0                    0.0                    1.0
# 2012-05-23        73600000.0                    0.0                    1.0
# 2012-05-24        50237200.0                    0.0                    1.0
#
# ...

# %% [markdown]
# ### Checking the shape of the data:

# %%
fb.shape
# Out:
# (1472, 12)

# %% [markdown]
# ### Saving the Data onto a CSV:

# %%
# fb.to_csv('/Users/adamdelreal/dsi/projects/capstone/data/facebook_quandle.csv')

# %% [markdown]
# -------
# <a class="anchor" id="Google"></a>
# ## Google's Financial History Since its IPO:

# %%
google = quandl.get(['WIKI/GOOGL'])

# %%
google.head()
# Out:
#             WIKI/GOOGL - Open  WIKI/GOOGL - High  WIKI/GOOGL - Low  \
# Date
# 2004-08-19             100.01             104.06             95.96
# 2004-08-20             101.01             109.08            100.50
# 2004-08-23             110.76             113.48            109.05
# 2004-08-24             111.24             111.60            103.57
# 2004-08-25             104.76             108.00            103.88
#
#             WIKI/GOOGL - Close  WIKI/GOOGL - Volume  WIKI/GOOGL - Ex-Dividend  \
# Date
# 2004-08-19             100.335           44659000.0                       0.0
# 2004-08-20             108.310           22834300.0                       0.0
# 2004-08-23             109.400           18256100.0                       0.0
# 2004-08-24             104.870           15247300.0                       0.0
# 2004-08-25             106.000            9188600.0                       0.0
#
#             WIKI/GOOGL - Split Ratio  WIKI/GOOGL - Adj. Open  \
# Date
# ...

# %% [markdown]
# ### Checking the shape of the data:

# %%
google.shape
# Out:
# (3424, 12)

# %% [markdown]
# ### Saving the Data onto a CSV:

# %%
# google.to_csv('/Users/adamdelreal/dsi/projects/capstone/data/google_quandle.csv')

# %% [markdown]
# -------
# <a class="anchor" id="Microsoft"></a>
#
# ## Microsoft's Financial History Since its IPO:

# %%
ms = quandl.get(['WIKI/MSFT'])
ms.head()
# Out:
#             WIKI/MSFT - Open  WIKI/MSFT - High  WIKI/MSFT - Low  \
# Date
# 1986-03-13             25.50             29.25             25.5
# 1986-03-14             28.00             29.50             28.0
# 1986-03-17             29.00             29.75             29.0
# 1986-03-18             29.50             29.75             28.5
# 1986-03-19             28.75             29.00             28.0
#
#             WIKI/MSFT - Close  WIKI/MSFT - Volume  WIKI/MSFT - Ex-Dividend  \
# Date
# 1986-03-13              28.00           3582600.0                      0.0
# 1986-03-14              29.00           1070000.0                      0.0
# 1986-03-17              29.50            462400.0                      0.0
# 1986-03-18              28.75            235300.0                      0.0
# 1986-03-19              28.25            166300.0                      0.0
#
#             WIKI/MSFT - Split Ratio  WIKI/MSFT - Adj. Open  \
# Date
# ...

# %% [markdown]
# ### Checking the shape of the data:

# %%
ms.shape
# Out:
# (8076, 12)

# %% [markdown]
# ### Saving the Data onto a CSV:

# %%
# ms.to_csv('/Users/adamdelreal/dsi/projects/capstone/data/microsoft_quandle.csv')

# %% [markdown]
# ------
# <a class="anchor" id="Twitter"></a>
# ## Twitter's Financial History Since its IPO:

# %%
twitter = quandl.get(['WIKI/TWTR'])
twitter.head()
# Out:
#             WIKI/TWTR - Open  WIKI/TWTR - High  WIKI/TWTR - Low  \
# Date
# 2013-11-07             45.10             50.09            44.00
# 2013-11-08             45.93             46.94            40.69
# 2013-11-11             40.50             43.00            39.40
# 2013-11-12             43.66             43.78            41.83
# 2013-11-13             41.03             42.87            40.76
#
#             WIKI/TWTR - Close  WIKI/TWTR - Volume  WIKI/TWTR - Ex-Dividend  \
# Date
# 2013-11-07              44.90         117701600.0                      0.0
# 2013-11-08              41.65          27925300.0                      0.0
# 2013-11-11              42.90          16113900.0                      0.0
# 2013-11-12              41.90           6316700.0                      0.0
# 2013-11-13              42.60           8688300.0                      0.0
#
#             WIKI/TWTR - Split Ratio  WIKI/TWTR - Adj. Open  \
# Date
# ...

# %% [markdown]
# ### Checking the shape of the data:

# %%
twitter.shape
# Out:
# (1102, 12)

# %% [markdown]
# ### Saving the Data onto a CSV:

# %%
# twitter.to_csv('/Users/adamdelreal/dsi/projects/capstone/data/twitter_quandle.csv')

# %% [markdown]
# ------
#
# <a class="anchor" id="IBM"></a>
# ## IBM's Financial History Since its IPO:

# %%
ibm = quandl.get(['WIKI/IBM'])
ibm.head()
# Out:
#             WIKI/IBM - Open  WIKI/IBM - High  WIKI/IBM - Low  \
# Date
# 1962-01-02            578.5            578.5           572.0
# 1962-01-03            572.0            577.0           572.0
# 1962-01-04            577.0            577.0           571.0
# 1962-01-05            570.5            570.5           559.0
# 1962-01-08            559.5            559.5           545.0
#
#             WIKI/IBM - Close  WIKI/IBM - Volume  WIKI/IBM - Ex-Dividend  \
# Date
# 1962-01-02            572.00            19360.0                     0.0
# 1962-01-03            577.00            14400.0                     0.0
# 1962-01-04            571.25            12800.0                     0.0
# 1962-01-05            560.00            18160.0                     0.0
# 1962-01-08            549.50            27200.0                     0.0
#
#             WIKI/IBM - Split Ratio  WIKI/IBM - Adj. Open  \
# Date
# 1962-01-02                     1.0             15.270839
# ...

# %% [markdown]
# ### Checking the shape of the data:

# %%
ibm.shape
# Out:
# (14155, 12)

# %% [markdown]
# ### Saving the Data onto a CSV:

# %%
# ibm.to_csv('/Users/adamdelreal/dsi/projects/capstone/data/ibm_quandle.csv')

# %% [markdown]
# ------
#
# <a class="anchor" id="Apple"></a>
# ## Apple's Stock History Since its IPO:

# %%
apple = quandl.get(['WIKI/AAPL'])
apple.head()
# Out:
#             WIKI/AAPL - Open  WIKI/AAPL - High  WIKI/AAPL - Low  \
# Date
# 1980-12-12             28.75             28.87            28.75
# 1980-12-15             27.38             27.38            27.25
# 1980-12-16             25.37             25.37            25.25
# 1980-12-17             25.87             26.00            25.87
# 1980-12-18             26.63             26.75            26.63
#
#             WIKI/AAPL - Close  WIKI/AAPL - Volume  WIKI/AAPL - Ex-Dividend  \
# Date
# 1980-12-12              28.75           2093900.0                      0.0
# 1980-12-15              27.25            785200.0                      0.0
# 1980-12-16              25.25            472000.0                      0.0
# 1980-12-17              25.87            385900.0                      0.0
# 1980-12-18              26.63            327900.0                      0.0
#
#             WIKI/AAPL - Split Ratio  WIKI/AAPL - Adj. Open  \
# Date
# ...

# %% [markdown]
# ### Checking the Shape of the Data:

# %%
apple.shape
# Out:
# (9400, 12)

# %% [markdown]
# ### Saving the Data onto the CSV:

# %%
# apple.to_csv('/Users/adamdelreal/dsi/projects/capstone/data/apple_quandle.csv')

# %% [markdown]
# -------
#
# <a class="anchor" id="JPM"></a>
# ## JP Morgan's Financial History Since its IPO:

# %%
jpm = quandl.get(['WIKI/JPM'])
jpm.head()
# Out:
#             WIKI/JPM - Open  WIKI/JPM - High  WIKI/JPM - Low  \
# Date
# 1983-12-30            44.00            44.50           43.50
# 1984-01-03            43.94            44.25           43.62
# 1984-01-04            44.84            45.87           44.25
# 1984-01-05            46.81            47.38           46.25
# 1984-01-06            46.88            47.38           46.38
#
#             WIKI/JPM - Close  WIKI/JPM - Volume  WIKI/JPM - Ex-Dividend  \
# Date
# 1983-12-30             44.00            47000.0                     0.0
# 1984-01-03             44.00            85667.0                     0.0
# 1984-01-04             45.87            65000.0                     0.0
# 1984-01-05             47.38            76467.0                     0.0
# 1984-01-06             46.88            43200.0                     0.0
#
#             WIKI/JPM - Split Ratio  WIKI/JPM - Adj. Open  \
# Date
# 1983-12-30                     1.0              3.074327
# ...

# %% [markdown]
# ### Checking the Shape of the Data:

# %%
jpm.shape
# Out:
# (8631, 12)

# %% [markdown]
# ### Saving the Data onto a CSV:

# %%
# jpm.to_csv('/Users/adamdelreal/dsi/projects/capstone/data/jpm_quandle.csv')

# %% [markdown]
# -------
#
# <a class="anchor" id="GS"></a>
# ## Goldman Sacks Financial History Since its IPO

# %%
gs = quandl.get(['WIKI/GS'])
gs.head()
# Out:
#             WIKI/GS - Open  WIKI/GS - High  WIKI/GS - Low  WIKI/GS - Close  \
# Date
# 1999-05-04           76.00           77.25          70.00            70.38
# 1999-05-05           69.88           69.88          66.25            69.13
# 1999-05-06           68.00           69.38          67.06            67.94
# 1999-05-07           67.94           74.88          66.75            74.13
# 1999-05-10           73.38           73.50          70.25            70.69
#
#             WIKI/GS - Volume  WIKI/GS - Ex-Dividend  WIKI/GS - Split Ratio  \
# Date
# 1999-05-04        22320900.0                    0.0                    1.0
# 1999-05-05         7565700.0                    0.0                    1.0
# 1999-05-06         2905700.0                    0.0                    1.0
# 1999-05-07         4862300.0                    0.0                    1.0
# 1999-05-10         2589400.0                    0.0                    1.0
#
# ...

# %% [markdown]
# ### Checking the Shape of the data:

# %%
gs.shape
# Out:
# (4755, 12)

# %% [markdown]
# ### Saving the Data onto a CSV:

# %%
# gs.to_csv('/Users/adamdelreal/dsi/projects/capstone/data/gs_quandle.csv')

# %% [markdown]
# ------
#
# <a class="anchor" id="BR"></a>
# ## BlackRock's Financial History Since its IPO

# %%
blackrock = quandl.get(['WIKI/BLK'])
blackrock.head()
# Out:
#             WIKI/BLK - Open  WIKI/BLK - High  WIKI/BLK - Low  \
# Date
# 1999-10-01            14.00            14.25           14.00
# 1999-10-04            14.00            14.13           14.00
# 1999-10-05            14.06            14.19           14.00
# 1999-10-06            14.13            14.88           14.13
# 1999-10-07            14.88            14.88           14.06
#
#             WIKI/BLK - Close  WIKI/BLK - Volume  WIKI/BLK - Ex-Dividend  \
# Date
# 1999-10-01             14.13          3162400.0                     0.0
# 1999-10-04             14.06           533400.0                     0.0
# 1999-10-05             14.19           270600.0                     0.0
# 1999-10-06             14.88           205400.0                     0.0
# 1999-10-07             14.13           214200.0                     0.0
#
#             WIKI/BLK - Split Ratio  WIKI/BLK - Adj. Open  \
# Date
# 1999-10-01                     1.0             10.216910
# ...

# %% [markdown]
# ### Checking the Shape of the data:

# %%
blackrock.shape
# Out:
# (4650, 12)

# %% [markdown]
# ### Saving the Data onto a CSV:

# %%
# blackrock.to_csv('/Users/adamdelreal/dsi/projects/capstone/data/blackrock_quandle.csv')

# %% [markdown]
# ------
#
# <a class="anchor" id="DOW"></a>
# ## DOW Jones:

# %%
dow = quandl.get(['WIKI/DOW'])
dow.head()
# Out:
#             WIKI/DOW - Open  WIKI/DOW - High  WIKI/DOW - Low  \
# Date
# 1972-06-01            92.28            92.28           91.75
# 1972-06-02            92.25            93.50           92.25
# 1972-06-05            93.00            93.12           92.75
# 1972-06-06            92.75            92.87           92.25
# 1972-06-07            92.13            92.13           90.87
#
#             WIKI/DOW - Close  WIKI/DOW - Volume  WIKI/DOW - Ex-Dividend  \
# Date
# 1972-06-01             92.00             5900.0                     0.0
# 1972-06-02             93.00            18000.0                     0.0
# 1972-06-05             92.75             7600.0                     0.0
# 1972-06-06             92.50             6100.0                     0.0
# 1972-06-07             90.87             9600.0                     0.0
#
#             WIKI/DOW - Split Ratio  WIKI/DOW - Adj. Open  \
# Date
# 1972-06-01                     1.0              1.657260
# ...

# %% [markdown]
# ### Checking the Shape of the Data:

# %%
dow.shape
# Out:
# (11415, 12)

# %% [markdown]
# ### Saving the Data onto a CSV:

# %%
# dow.to_csv('/Users/adamdelreal/dsi/projects/capstone/data/dow_quandle.csv')

# %% [markdown]
# -----
#
# <a class="anchor" id="Moodys"></a>
# ## Moody's

# %%
moodys = quandl.get(['WIKI/MCO'])
moodys.head()
# Out:
#             WIKI/MCO - Open  WIKI/MCO - High  WIKI/MCO - Low  \
# Date
# 1994-10-31            16.38            16.62           16.38
# 1994-11-01            16.62            16.62           16.38
# 1994-11-02            16.50            16.50           16.38
# 1994-11-03            16.38            16.50           16.25
# 1994-11-04            16.38            16.50           16.25
#
#             WIKI/MCO - Close  WIKI/MCO - Volume  WIKI/MCO - Ex-Dividend  \
# Date
# 1994-10-31             16.62           992100.0                     0.0
# 1994-11-01             16.50          1088200.0                     0.0
# 1994-11-02             16.38          1174100.0                     0.0
# 1994-11-03             16.38          1030400.0                     0.0
# 1994-11-04             16.25          1331900.0                     0.0
#
#             WIKI/MCO - Split Ratio  WIKI/MCO - Adj. Open  \
# Date
# 1994-10-31                     1.0              1.033628
# ...

# %% [markdown]
# ### Checking the Shape of the data:

# %%
moodys.shape
# Out:
# (5892, 12)

# %% [markdown]
# ### Saving the Data onto a CSV:

# %%
# moodys.to_csv('/Users/adamdelreal/dsi/projects/capstone/data/moodys_quandle.csv')
